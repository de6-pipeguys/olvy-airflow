# %%
! pip install pyspark==3.5.3

# %%
from pyspark.sql import SparkSession
import os

# Java 11 경로 지정, hadoop 환경변수 지정
os.environ["JAVA_HOME"] = "C:/Users/82102/AppData/Local/Programs/Eclipse Adoptium/jdk-11.0.27.6-hotspot"
os.environ["HADOOP_HOME"] = "C:/hadoop"

# SparkSession 생성 (AccessKey, SecretKey는 이후 .env로 빼기)
spark = SparkSession.builder \
        .appName("olvy-preprocessing") \
        .master("local[*]") \
        .config("spark.jars.packages", "org.apache.hadoop:hadoop-aws:3.3.2") \
        .config("spark.hadoop.fs.s3a.access.key", "AKIA4RRVVY55Q7PYTBG4") \
        .config("spark.hadoop.fs.s3a.secret.key", "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") \
        .config("spark.hadoop.fs.s3a.endpoint", "s3.ap-northeast-2.amazonaws.com") \
        .config("spark.hadoop.fs.s3a.impl", "org.apache.hadoop.fs.s3a.S3AFileSystem") \
        .getOrCreate()

# %%
df = spark.read.option("multiLine", "true").json("s3a://de6-team5-bucket/raw_data/pb/shingmulnara/pb_shingmulnara_result_20250715_131506.json")
df.show()
# Out:
# +---------+---------+--------------------------+--------+-------------------+-------------------------------+--------+----------------------------------+------------------------------------+----+---------+------------+-------------+------+------+------+------+------+------------------------+---------+------------+
# |avgReview|brandName|                  capacity|category|          createdAt|                         detail|flagList|                         goodsName|                          ingredient|isPb|isSoldout|numOfReviews|originalPrice|pctOf1|pctOf2|pctOf3|pctOf4|pctOf5|            reviewDetail|salePrice|totalComment|
# +---------+---------+--------------------------+--------+-------------------+-------------------------------+--------+----------------------------------+------------------------------------+----+---------+------------+-------------+------+------+------+------+------+------------------------+---------+------------+
# ...
